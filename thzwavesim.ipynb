# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
c = 299792458
lam = 800*10**-9
omega = 2*np.pi*c/(lam*10**12)

# %%
omega
# Out:
# 2354.564459136066

# %%
t = np.linspace(0,0.6,1000)

# %%
f = np.exp(-2*np.log(2)*((t-0.3)/0.1)**2)*np.cos(omega*t)

# %%
plt.figure()
plt.plot(t,f, 'r')
plt.xlabel('Time(ps)')
plt.ylabel('Electric Field a.u.')
plt.savefig('nearirwave.svg')
plt.show()

# %%
k = np.exp(-2*np.log(2)*((t-0.3)/0.1)**2)

# %%
l = k**2

# %%
#m = derivative with respect to t (l)

# %%
m = -554.518*np.exp(-277.259*(-0.3+t)**2)*(-0.3+t)

# %%
#n = derivative with respect to t (m)

# %%
n = -554.5177444479563*np.exp(-277.259*(-0.3+t)**2)+307490*np.exp(-277.259*(-0.3+t)**2)*(-0.3+t)**2

# %%
plt.figure()
plt.plot(t,-n/554.5177444479563)
plt.xlabel('Time(ps)')
plt.ylabel('Electric Field a.u.')
#plt.savefig('thzwave.svg')
plt.show()

# %%
plt.figure()
plt.plot(t,f)
plt.plot(t,-n/554.5177444479563)
plt.xlabel('Time(ps)')
plt.ylabel('Electric Field a.u.')
plt.show()
